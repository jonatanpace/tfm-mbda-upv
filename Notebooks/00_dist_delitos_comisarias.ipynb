# %%
import pandas as pd
import numpy as np
from geopy.distance import geodesic
from pandarallel import pandarallel
# Out:
# /var/folders/rl/8r_3m_r94_j58zn6wmg4r9m80000gn/T/ipykernel_1661/3724013199.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
delitos = pd.read_csv('../Datasets/delitos_2022.csv')
robos_all_years = pd.read_csv('../Datasets/robos_all_years.csv')
comisarias = pd.read_csv('../Datasets/comisarias-policia-de-la-ciudad.csv')

# %%
robos_all_years.shape
# Out:
# (653525, 19)

# %%
robos_all_years.duplicated(subset=['latitud', 'longitud']).sum()
# Out:
# 354093

# %%
comisarias.head()
# Out:
#         long        lat  id                 nombre       calle  altura calle2  \
# 0 -58.373245 -34.601906   1  Comisaria Vecinal 1-D     Lavalle     451    NaN
# 1 -58.424926 -34.628641  37  Comisaria Vecinal 5-B       Muñiz    1250    NaN
# 2 -58.439501 -34.608979  39  Comisaria Vecinal 6-A  Diaz Velez    5152    NaN
# 3 -58.448087 -34.626780   8  Comisaria Vecinal 7-B       Valle    1454    NaN
# 4 -58.453221 -34.620382  38    Comisaria Comunal 6  Avellaneda    1548    NaN
#
#              direccion             telefonos  \
# 0          LAVALLE 451        4322-8033/8221
# 1           MUÑIZ 1250  4922-1229 /4922-3333
# 2  DIAZ VELEZ AV. 5152        4982-4509/4520
# 3           VALLE 1454        4432-3334/3922
# 4  AVELLANEDA AV. 1548        4632-9051/9129
#
#                                observaciones  observaciones_2       barrio  \
# 0                                        NaN              NaN  SAN NICOLAS
# 1                                        NaN              NaN        BOEDO
# 2                                        NaN              NaN    CABALLITO
# 3  Ubicada en comuna 6, dependencia comuna 7              NaN    CABALLITO
# 4                                        NaN              NaN    CABALLITO
#
#    comuna  codigo_postal codigo_postal_argentino
# 0       1         1047.0                C1047AAI
# 1       5         1255.0                C1255ACD
# 2       6         1405.0                C1405DCT
# 3       6         1406.0                C1406GTH
# 4       6         1406.0                C1406FYN

# %%
robos_all_years
# Out:
#         id-mapa  anio        mes        dia       fecha  franja   tipo  \
# 0        252569  2019      ENERO      LUNES  2019-01-28     8.0  Hurto
# 1        252570  2019      MARZO      LUNES  2019-03-04    11.0  Hurto
# 2        252571  2019      ABRIL  MIERCOLES  2019-04-10    18.0   Robo
# 3        252572  2019  NOVIEMBRE      LUNES  2019-11-18    12.0  Hurto
# 4        252573  2019      ABRIL      LUNES  2019-04-01    17.0   Robo
# ...         ...   ...        ...        ...         ...     ...    ...
# 653520   831327  2017  DICIEMBRE    DOMINGO  2017-12-31    23.0  Hurto
# 653521   831330  2017  DICIEMBRE    DOMINGO  2017-12-31    14.0  Hurto
# 653522   831333  2017  DICIEMBRE    DOMINGO  2017-12-31     0.0  Hurto
# 653523   831336  2017  DICIEMBRE    DOMINGO  2017-12-31     9.0  Hurto
# 653524   831339  2017  DICIEMBRE    DOMINGO  2017-12-31     3.0  Hurto
#
#             subtipo uso_arma uso_moto            barrio  comuna    latitud  \
# 0       Hurto total       NO       NO  PARQUE PATRICIOS     4.0 -34.630835
# 1       Hurto total       NO       NO  PARQUE PATRICIOS     4.0 -34.628442
# 2        Robo total       NO       NO  PARQUE PATRICIOS     4.0 -34.630313
# 3       Hurto total       NO       NO  PARQUE PATRICIOS     4.0 -34.630163
# 4        Robo total       NO       NO  PARQUE PATRICIOS     4.0 -34.629944
# ...             ...      ...      ...               ...     ...        ...
# 653520  Hurto total       NO       NO     VILLA URQUIZA    12.0 -34.569537
# 653521  Hurto total       NO       NO          BELGRANO    13.0 -34.559850
# 653522  Hurto total       NO       NO             NUÑEZ    13.0 -34.552862
# 653523  Hurto total       NO       NO  VILLA PUEYRREDON    12.0 -34.572164
# 653524  Hurto total       NO       NO          RECOLETA     2.0 -34.592010
#
#          longitud  cantidad  mes_numero  dia_numero  dia_mes_numero anio_mes
# 0      -58.391528         1           1           1              28  2019-01
# 1      -58.391876         1           3           1               4  2019-03
# 2      -58.391512         1           4           3              10  2019-04
# 3      -58.391542         1          11           1              18  2019-11
# 4      -58.391882         1           4           1               1  2019-04
# ...           ...       ...         ...         ...             ...      ...
# 653520 -58.488005         1          12           7              31  2017-12
# 653521 -58.452968         1          12           7              31  2017-12
# 653522 -58.462993         1          12           7              31  2017-12
# 653523 -58.505348         1          12           7              31  2017-12
# 653524 -58.398274         1          12           7              31  2017-12
#
# [653525 rows x 19 columns]

# %%
pandarallel.initialize()

def calcular_distancia(row, df2):
    lat_df1, lon_df1 = row['latitud'], row['longitud']
    distances = df2.apply(lambda x: geodesic((lat_df1, lon_df1), (x['lat'], x['long'])).meters, axis=1)
    min_distance_idx = distances.idxmin()
    min_distance = distances[min_distance_idx]
    id_comisaria_cercana = df2.loc[min_distance_idx, 'id']
    return pd.Series({'distancia': min_distance, 'id_comisaria': id_comisaria_cercana})

def calcular_distancias_cercanas(df1, df2):
    resultados_df = df1.parallel_apply(calcular_distancia, df2=df2, axis=1)
    resultados_df.insert(0, 'id_delito', df1['id-mapa'])
    return resultados_df


distancia_entre_delitos_y_comisaria = calcular_distancias_cercanas(robos_all_years, comisarias)
distancia_entre_delitos_y_comisaria.to_csv('../Datasets/distancia_entre_delito_y_comisaria.csv', index=False)
distancia_entre_delitos_y_comisaria
# Out:
# INFO: Pandarallel will run on 8 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.
#         id_delito    distancia  id_comisaria
# 0          252569   917.794982          42.0
# 1          252570   657.718990          42.0
# 2          252571   859.954510          42.0
# 3          252572   843.603533          42.0
# 4          252573   822.756662          42.0
# ...           ...          ...           ...
# 653520     831327   700.162806          26.0
# 653521     831330   306.117267          17.0
# 653522     831333   167.747169          18.0
# 653523     831336  1578.768606          49.0
# 653524     831339   551.252248          11.0
#
# [653525 rows x 3 columns]

# %%
distancia_entre_delitos_y_comisaria = pd.read_csv('../Datasets/distancia_entre_delito_y_comisaria.csv')

# Definir los límites de los intervalos
bins = [-np.inf, 100, 300, 500, 1000, np.inf]

# Definir los nombres de las etiquetas para cada intervalo
labels = ['<100', '100-300', '301-500', '501-1000', '>1000']


# Renombr columnas

distancia_entre_delitos_y_comisaria.rename(columns={'distancia':'distancia_a_comisaria_m'}, inplace=True)
distancia_entre_delitos_y_comisaria['distancia_a_comisaria_m'] = distancia_entre_delitos_y_comisaria['distancia_a_comisaria_m'].round(0)

distancia_entre_delitos_y_comisaria['distancia_a_comisaria_m'] = distancia_entre_delitos_y_comisaria['distancia_a_comisaria_m'].astype('int32')
distancia_entre_delitos_y_comisaria['id_comisaria'] = distancia_entre_delitos_y_comisaria['id_comisaria'].astype('int32')

# Crear la columna categórica usando pd.cut()
distancia_entre_delitos_y_comisaria['distancia_a_comisaria_grupo'] = pd.cut(distancia_entre_delitos_y_comisaria['distancia_a_comisaria_m'], 
                                                                    bins = bins, 
                                                                    labels = labels, 
                                                                    right = False)



distancia_entre_delitos_y_comisaria.to_csv('../Datasets/distancia_entre_delito_y_comisaria_clean.csv', index=False)

# %%
distancia_entre_delitos_y_comisaria
# Out:
#         id_delito  distancia_a_comisaria_m  id_comisaria  \
# 0          252569                      918            42
# 1          252570                      658            42
# 2          252571                      860            42
# 3          252572                      844            42
# 4          252573                      823            42
# ...           ...                      ...           ...
# 653520     831327                      700            26
# 653521     831330                      306            17
# 653522     831333                      168            18
# 653523     831336                     1579            49
# 653524     831339                      551            11
#
#        distancia_a_comisaria_grupo
# 0                         501-1000
# 1                         501-1000
# 2                         501-1000
# 3                         501-1000
# 4                         501-1000
# ...                            ...
# 653520                    501-1000
# 653521                     301-500
# 653522                     100-300
# 653523                       >1000
# 653524                    501-1000
#
# [653525 rows x 4 columns]

# %%
distancia_entre_delitos_y_comisaria.distancia.hist()
# Out:
# <Axes: >

# %%
distancia_entre_delitos_y_comisaria.distancia_categoria.hist()
# Out:
# <Axes: >

# %%
distancia_entre_delitos_y_comisaria.sort_values('distancia', ascending=True)
# Out:
#         id_delito  distancia  id_comisaria distancia_categoria
# 214254     198933        0.0          57.0                <100
# 138977     602546        0.0          11.0                <100
# 202720     819664        0.0           1.0                <100
# 26667      280744        0.0          10.0                <100
# 152458     644198        0.0           7.0                <100
# ...           ...        ...           ...                 ...
# 388930      49565     2786.0          52.0               >1000
# 9488       263010     2786.0          52.0               >1000
# 359471      19105     2789.0          53.0               >1000
# 420420      82817     2789.0          53.0               >1000
# 415460      77499     2789.0          53.0               >1000
#
# [653525 rows x 4 columns]

# %%
(distancia_entre_delitos_y_comisaria['distancia_categoria'] == '<100').sum()
# Out:
# 7999

# %%
### BACKUP CODE ###

def calcular_distancias_cercanas(df1, df2):
    resultados = []

    # Pre-cálculo de las distancias
    distancias = {}
    for index2, row_df2 in df2.iterrows():
        lat_df2, lon_df2, id_df2 = row_df2['lat'], row_df2['long'], row_df2['id']
        distancias[id_df2] = (lat_df2, lon_df2)

    for index1, row_df1 in df1.iterrows():
        lat_df1, lon_df1, id_df1 = row_df1['latitud'], row_df1['longitud'], row_df1['id-mapa']
        
        min_distancia = float('inf')
        id_comisaria_cercana = None
        
        for id_comisaria, (lat_df2, lon_df2) in distancias.items():
            distancia = geodesic((lat_df1, lon_df1), (lat_df2, lon_df2)).meters
            if distancia < min_distancia:
                min_distancia = distancia
                id_comisaria_cercana = id_comisaria

        resultados.append({'id_delito': id_df1, 'distancia': min_distancia, 'id_comisaria': id_comisaria_cercana})
        #print(index1)

    resultados_df = pd.DataFrame(resultados)
    return resultados_df

distancia_entre_delitos_y_comisaria = calcular_distancias_cercanas(robos_all_years.head(100), comisarias)

# %%
comisarias
# Out:
#          long        lat  id                                   nombre  \
# 0  -58.373245 -34.601906   1                    Comisaria Vecinal 1-D
# 1  -58.424926 -34.628641  37                    Comisaria Vecinal 5-B
# 2  -58.439501 -34.608979  39                    Comisaria Vecinal 6-A
# 3  -58.448087 -34.626780   8                    Comisaria Vecinal 7-B
# 4  -58.453221 -34.620382  38                      Comisaria Comunal 6
# 5  -58.380178 -34.594643  10                      Comisaria Comunal 1
# 6  -58.385608 -34.622670  43   Comisaria Vecinal 1-C (edificio anexo)
# 7  -58.392359 -34.591137  11                      Comisaria Comunal 2
# 8  -58.390749 -34.622587  42                    Comisaria Vecinal 1-C
# 9  -58.406719 -34.594079  29                    Comisaria Vecinal 2-B
# 10 -58.374147 -34.620278   2   Comisaria Vecinal 1-B (edificio anexo)
# 11 -58.403227 -34.626032  41                    Comisaria Vecinal 3-B
# 12 -58.415927 -34.587732  34                   Comisaria Vecinal 14-A
# 13 -58.363990 -34.624279  40                    Comisaria Vecinal 1-E
# 14 -58.360588 -34.634169  12                    Comisaria Vecinal 4-C
# 15 -58.374909 -34.638063  13   Comisaria Vecinal 4-D (edificio anexo)
# 16 -58.441084 -34.599321  45                   Comisaria Vecinal 15-B
# 17 -58.388896 -34.601940   3                    Comisaria Vecinal 1-A
# 18 -58.374727 -34.647284  15                    Comisaria Vecinal 4-D
# 19 -58.438956 -34.573309  32                   Comisaria Vecinal 14-B
# 20 -58.456285 -34.560145  17                   Comisaria Vecinal 13-C
# 21 -58.417156 -34.644795  47                    Comisaria Vecinal 4-B
# 22 -58.463327 -34.551376  18                   Comisaria Vecinal 13-B
# 23 -58.454267 -34.677358  19                    Comisaria Vecinal 8-B
# 24 -58.475821 -34.573116  33                   Comisaria Vecinal 12-C
# 25 -58.458256 -34.630924  48                      Comisaria Comunal 7
# 26 -58.490057 -34.578689  49                   Comisaria Vecinal 12-B
# 27 -58.378577 -34.617162   4                    Comisaria Vecinal 1-B
# 28 -58.476337 -34.641462  20                    Comisaria Vecinal 9-B
# 29 -58.472991 -34.611120  21                     Comisaria Comunal 11
# 30 -58.501166 -34.661994  22                      Comisaria Comunal 9
# 31 -58.483780 -34.628807  23                     Comisaria Comunal 10
# 32 -58.524039 -34.629536  50                   Comisaria Vecinal 10-B
# 33 -58.515606 -34.598315  27                   Comisaria Vecinal 11-B
# 34 -58.499367 -34.589713  24  Comisaria Vecinal 11-B (edificio anexo)
# 35 -58.474889 -34.679035  25                    Comisaria Vecinal 8-A
# 36 -58.482525 -34.565145  26                   Comisaria Vecinal 12-A
# 37 -58.394789 -34.603418   5                      Comisaria Comunal 3
# 38 -58.464821 -34.616114  51                    Comisaria Vecinal 7-C
# 39 -58.444068 -34.554822  52                     Comisaria Comunal 13
# 40 -58.468944 -34.683121  44                      Comisaria Comunal 8
# 41 -58.413659 -34.581270  53                     Comisaria Comunal 14
# 42 -58.505087 -34.639967  54                   Comisaria Vecinal 10-C
# 43 -58.404011 -34.603211   6                    Comisaria Vecinal 3-A
# 44 -58.409280 -34.617058  35   Comisaria Vecinal 3-A (edificio anexo)
# 45 -58.415559 -34.604429   7                      Comisaria Comunal 5
# 46 -58.490909 -34.551103  56                     Comisaria Comunal 12
# 47 -58.451230 -34.590420  57                     Comisaria Comunal 15
# 48 -58.402830 -34.641950  55                      Comisaria Comunal 4
#
#                         calle  altura    calle2  \
# 0                     Lavalle     451       NaN
# 1                       Muñiz    1250       NaN
# 2                  Diaz Velez    5152       NaN
# 3                       Valle    1454       NaN
# 4                  Avellaneda    1548       NaN
# 5                    Suipacha    1156       NaN
# 6                    San Jose    1224       NaN
# 7             Las Heras Gral.    1861       NaN
# 8                Av. San Juan    1757       NaN
# 9                     Charcas    2844       NaN
# 10                       Peru    1056       NaN
# 11                  Catamarca    1345       NaN
# 12             Julian alvarez    2373       NaN
# 13            Av. Ing. Huergo    1500       NaN
# 14                     Pinzon     456       NaN
# 15              Montes de Oca     861       NaN
# 16                    Camargo     645       NaN
# 17                    Tucuman    1560       NaN
# 18                 California    1850       NaN
# 19                    Cabildo     232       NaN
# 20                    Mendoza    2263       NaN
# 21                    Quilmes     456       NaN
# 22                       Cuba    3145       NaN
# 23               Escalada Av.    4347       NaN
# 24                  Juramento    4367       NaN
# 25  Av. Cnel Esteban Bonorino     258       NaN
# 26                   Olazabal    5437       NaN
# 27                    Tacuari     770       NaN
# 28                   Remedios    3748       NaN
# 29          Bufano Alfredo R.    1800       NaN
# 30       Lisandro de la Torre    2343       NaN
# 31                 Chivilicoy     453       NaN
# 32   Manuel Porcel de Peralta     726       NaN
# 33                 Jose Cubas    4154       NaN
# 34                      Nazca    4254       NaN
# 35      Leguizamon Martiniano    4347       NaN
# 36                    Machain    3045       NaN
# 37                    Lavalle    1958       NaN
# 38                      Gaona    2738       NaN
# 39                 Artilleros    2081       NaN
# 40                   Ana Diaz       0  Cafayate
# 41      Republica Arabe Siria    2961       NaN
# 42                   Basualdo     165       NaN
# 43                    Lavalle    2625       NaN
# 44              Urquiza Gral.     544       NaN
# 45               Billinghurst     471       NaN
# 46                    Ramallo    4398       NaN
# 47                     Guzman     396       NaN
# 48                   Zavaleta     425       NaN
#
#                            direccion  \
# 0                        LAVALLE 451
# 1                         MUÑIZ 1250
# 2                DIAZ VELEZ AV. 5152
# 3                         VALLE 1454
# 4                AVELLANEDA AV. 1548
# 5                      SUIPACHA 1156
# 6                      SAN JOSE 1224
# 7         LAS HERAS GENERAL AV. 1861
# 8                  SAN JUAN AV. 1757
# 9                       CHARCAS 2844
# 10                         PERU 1056
# 11                    CATAMARCA 1345
# 12              ALVAREZ, JULIAN 2373
# 13             HUERGO, ING. AV. 1500
# 14                        PINZON 456
# 15         MONTES DE OCA, MANUEL 861
# 16                       CAMARGO 645
# 17                      TUCUMAN 1560
# 18                   CALIFORNIA 1850
# 19                   CABILDO AV. 232
# 20                      MENDOZA 2263
# 21                       QUILMES 456
# 22                         CUBA 3145
# 23                 ESCALADA AV. 4347
# 24                    JURAMENTO 4367
# 25  BONORINO, ESTEBAN, Cnel. AV. 258
# 26                 OLAZABAL AV. 5437
# 27                       TACUARI 770
# 28                     REMEDIOS 3748
# 29           BUFANO, ALFREDO R. 1800
# 30    DE LA TORRE, LISANDRO AV. 2343
# 31                     CHIVILCOY 453
# 32     PORCEL DE PERALTA, MANUEL 726
# 33                  CUBAS, JOSE 4154
# 34                        NAZCA 4254
# 35       LEGUIZAMON, MARTINIANO 4347
# 36                      MACHAIN 3045
# 37                      LAVALLE 1958
# 38                    GAONA AV. 2738
# 39                   ARTILLEROS 2081
# 40               DIAZ ANA Y CAFAYATE
# 41        REPUBLICA ARABE SIRIA 2961
# 42                      BASUALDO 165
# 43                      LAVALLE 2625
# 44                URQUIZA, Gral. 544
# 45                  BILLINGHURST 471
# 46                      RAMALLO 4398
# 47                        GUZMAN 396
# 48                      ZAVALETA 425
#
#                                     telefonos  \
# 0                              4322-8033/8221
# 1                        4922-1229 /4922-3333
# 2                              4982-4509/4520
# 3                              4432-3334/3922
# 4                              4632-9051/9129
# 5                         4393-0076/3333/7058
# 6                              4306-3333/4067
# 7                              4801-1698/3333
# 8                   4304-3203/4300 /4305-3333
# 9                              4822-3333/6311
# 10                   4307-0537/4361 -8054 /66
# 11                             4941-3333/4079
# 12                      4821-5056 / 4823-3333
# 13                                        NaN
# 14                       4361-4444 /4362-6875
# 15                                  4301-3333
# 16                      4854-1747 / 4855-3333
# 17             4371-3333 /4373-6194/4374-0454
# 18                 4300-6338 / 4307-4644/5153
# 19                       4771-3333 /4773-3315
# 20                   4781-3333/8936/4784-0651
# 21                             4911-4444/5506
# 22             4701-9168 /4702-3337/4703-3333
# 23                                        NaN
# 24                             4544-3330/4747
# 25                             4631-3333/7827
# 26                       4521-0028/ 4522-3333
# 27                       4331-9643 /4342-3333
# 28                       4672-1824/ 4674-3111
# 29             4581-3155/ 4582-3333/4585-5458
# 30                             4687-3333/6478
# 31                             4671-2209/4444
# 32                   4641-3333/3827/4642-7777
# 33  4501-3333/4111/ 4503-9603/ 4504-3333/5555
# 34                             4572-3333/3526
# 35                       4601-3333/ 4602-3333
# 36                                  4541-8142
# 37                             4953-2273/3323
# 38                             4581-1254/4444
# 39                             4784-4047/9940
# 40                             4605-2031/2090
# 41              4801-3332/4805-7928/4806-1666
# 42                                  4635-2011
# 43                 4961-3333/7342 / 4964-3421
# 44                4923-3171 / 4931-3333 /3531
# 45                       4861-5507 /4862-3333
# 46                                  4546-5600
# 47                                  4309-9615
# 48                                  5091-6100
#
#                                         observaciones  observaciones_2  \
# 0                                                 NaN              NaN
# 1                                                 NaN              NaN
# 2                                                 NaN              NaN
# 3           Ubicada en comuna 6, dependencia comuna 7              NaN
# 4                                                 NaN              NaN
# 5                                                 NaN              NaN
# 6                                                 NaN              NaN
# 7                                                 NaN              NaN
# 8                                                 NaN              NaN
# 9                                                 NaN              NaN
# 10                                                NaN              NaN
# 11                                                NaN              NaN
# 12                                                NaN              NaN
# 13                                                NaN              NaN
# 14                                                NaN              NaN
# 15                                                NaN              NaN
# 16                                                NaN              NaN
# 17                                                NaN              NaN
# 18                                                NaN              NaN
# 19                                                NaN              NaN
# 20                                                NaN              NaN
# 21                                                NaN              NaN
# 22                                                NaN              NaN
# 23                                                NaN              NaN
# 24                                                NaN              NaN
# 25                                                NaN              NaN
# 26                                                NaN              NaN
# 27                                                NaN              NaN
# 28                                                NaN              NaN
# 29                                                NaN              NaN
# 30                                                NaN              NaN
# 31                                                NaN              NaN
# 32                                                NaN              NaN
# 33                                                NaN              NaN
# 34        Ubicada en comuna 12, dependencia comuna 11              NaN
# 35                                                NaN              NaN
# 36                                                NaN              NaN
# 37                                                NaN              NaN
# 38                                                NaN              NaN
# 39                                                NaN              NaN
# 40                                                NaN              NaN
# 41                                                NaN              NaN
# 42                                                NaN              NaN
# 43                                                NaN              NaN
# 44                                                NaN              NaN
# 45                                                NaN              NaN
# 46  Esta comisaria cuenta con una dependencia del ...              NaN
# 47  Esta comisaria cuenta con una dependencia del ...              NaN
# 48  Esta comisaria cuenta con una dependencia del ...              NaN
#
#                barrio  comuna  codigo_postal codigo_postal_argentino
# 0         SAN NICOLAS       1         1047.0                C1047AAI
# 1               BOEDO       5         1255.0                C1255ACD
# 2           CABALLITO       6         1405.0                C1405DCT
# 3           CABALLITO       6         1406.0                C1406GTH
# 4           CABALLITO       6         1406.0                C1406FYN
# 5              RETIRO       1         1008.0                C1008AAX
# 6        CONSTITUCION       1         1136.0                C1136AAB
# 7            RECOLETA       2         1127.0                C1127AAA
# 8        CONSTITUCION       1         1148.0                C1148AAF
# 9            RECOLETA       2         1425.0                C1425BMH
# 10          SAN TELMO       1         1068.0                C1068AAL
# 11      SAN CRISTOBAL       3         1246.0                C1246AAC
# 12            PALERMO      14         1425.0                C1425DHI
# 13      PUERTO MADERO       1         1107.0                C1107APO
# 14               BOCA       4         1161.0                C1161ACJ
# 15           BARRACAS       4         1270.0                C1270AAI
# 16       VILLA CRESPO      15         1414.0                C1414AHM
# 17        SAN NICOLAS       1         1050.0                C1050AAF
# 18           BARRACAS       4         1289.0                C1289AAL
# 19            PALERMO      14         1426.0                C1426AAP
# 20           BELGRANO      13         1428.0                C1428DKK
# 21      NUEVA POMPEYA       4         1437.0                C1437DLJ
# 22              NUÑEZ      13         1429.0                C1429AXG
# 23      VILLA SOLDATI       8            NaN                     NaN
# 24      VILLA URQUIZA      12         1430.0                C1430BSU
# 25             FLORES       7         1406.0                C1406DMF
# 26      VILLA URQUIZA      12         1431.0                C1431CGK
# 27          MONSERRAT       1         1071.0                C1071AAP
# 28  PARQUE AVELLANEDA       9         1407.0                C1407HJJ
# 29  VILLA GRAL. MITRE      11         1416.0                C1416AJL
# 30          MATADEROS       9         1440.0                C1440ECL
# 31           FLORESTA      10            NaN                     NaN
# 32          VERSALLES      10         1408.0                C1408CBJ
# 33       VILLA DEVOTO      11         1419.0                C1419GOH
# 34   VILLA PUEYRREDON      12         1419.0                C1419DFS
# 35       VILLA LUGANO       8         1439.0                C1439FSE
# 36      VILLA URQUIZA      12         1430.0                C1430DYA
# 37          BALVANERA       3         1051.0                C1051ABD
# 38             FLORES       7         1416.0                C1416DSP
# 39           BELGRANO      13         1428.0                C1428AUE
# 40       VILLA LUGANO       8            NaN                     NaN
# 41            PALERMO      14         1425.0                C1425EYI
# 42         VILLA LURO      10         1408.0                C1408HUC
# 43          BALVANERA       3         1052.0                C1052AAG
# 44          BALVANERA       3         1221.0                C1221ADB
# 45            ALMAGRO       5         1174.0                C1174ABG
# 46           SAAVEDRA      12         1430.0                C1430CQD
# 47          CHACARITA      15         1427.0                C1427BOQ
# 48   PARQUE PATRICIOS       4         1437.0                C1437EYI

# %%
comisarias['id']
# Out:
# 0      1
# 1     37
# 2     39
# 3      8
# 4     38
# 5     10
# 6     43
# 7     11
# 8     42
# 9     29
# 10     2
# 11    41
# 12    34
# 13    40
# 14    12
# 15    13
# 16    45
# 17     3
# 18    15
# 19    32
# 20    17
# 21    47
# 22    18
# 23    19
# 24    33
# 25    48
# 26    49
# 27     4
# 28    20
# 29    21
# 30    22
# 31    23
# 32    50
# 33    27
# 34    24
# 35    25
# 36    26
# 37     5
# 38    51
# 39    52
# 40    44
# 41    53
# 42    54
# 43     6
# 44    35
# 45     7
# 46    56
# 47    57
# 48    55
# Name: id, dtype: int64

# %%
# código para validar las distancias

id_delito = 19105
id_comisaria = 2


delito_i =(robos_all_years[robos_all_years['id-mapa'] == id_delito]['latitud'].iloc[0], 
           robos_all_years[robos_all_years['id-mapa'] == id_delito]['longitud'].iloc[0])


comisaria_i =(comisarias[comisarias['id'] == id_comisaria]['lat'].iloc[0],
               comisarias[comisarias['id'] == id_comisaria]['long'].iloc[0])

min_distancia = float('inf')
for id_comisaria in comisarias['id']:
    comisaria_i =(comisarias[comisarias['id'] == id_comisaria]['lat'].iloc[0],
               comisarias[comisarias['id'] == id_comisaria]['long'].iloc[0])
    distancia = geodesic((delito_i), (comisaria_i)).meters
    if distancia < min_distancia:
        min_distancia = distancia
        print(min_distancia)
# Out:
# 6276.359289672356
# 5250.825720446756
# 4338.78122810816
# 4254.744328535313
# 3513.0939279263685
# 3018.58741380415
# 2814.2073455060313
# 2788.885768118369

# %%
delitos[delitos['id-mapa'] == 102]
